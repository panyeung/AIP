# %%
import pandas as pd
import numpy as np
import json

# %%
# open traffic.txt file
with open("CityIQ-Starter-Code-Python/traffic.txt", "r") as file:
    data = file.read()
jsondata = json.loads(data)

# normalize json
from pandas.io.json import json_normalize
df = pd.DataFrame(json_normalize(jsondata))
df.head()
# Out:
#                                assetUid eventType locationUid  \
# 0  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT    f57e7d59
# 1  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT    f57e7d59
# 2  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT    f57e7d59
# 3  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT    f57e7d59
# 4  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT    f57e7d59
#
#    measures.counter_direction  measures.counter_direction_speed  \
# 0                       289.0                               0.0
# 1                       289.0                               0.0
# 2                       289.0                               0.0
# 3                       289.0                               0.0
# 4                       289.0                               0.0
#
#    measures.counter_direction_vehicleCount  measures.direction  \
# 0                                      0.0               109.0
# 1                                      0.0               109.0
# 2                                      0.0               109.0
# 3                                      0.0               109.0
# 4                                      0.0               109.0
#
#    measures.speed  measures.vehicleCount  \
# 0       21.443278                    1.0
# 1        0.000000                    0.0
# 2       16.276961                    3.0
# 3       13.893564                    1.0
# 4       18.337332                    1.0
#
#   properties.counter_direction_vehicleType properties.directionUnit  \
# 0                            small_vehicle                   DEGREE
# 1                            large_vehicle                   DEGREE
# 2                            small_vehicle                   DEGREE
# 3                            large_vehicle                   DEGREE
# 4                            small_vehicle                   DEGREE
#
#     properties.eventUid properties.speedUnit properties.vehicleType  \
# 0  MTU3ODU1NDU5NTk5Ng==       METERS_PER_SEC          small_vehicle
# 1  MTU3ODU1NDU5NTk5Ng==       METERS_PER_SEC          large_vehicle
# 2  MTU3ODU1NDYyNjEyMQ==       METERS_PER_SEC          small_vehicle
# 3  MTU3ODU1NDYyNjEyMQ==       METERS_PER_SEC          large_vehicle
# 4  MTU3ODU1NDY1NjE3OQ==       METERS_PER_SEC          small_vehicle
#
#        timestamp
# 0  1578554595996
# 1  1578554595996
# 2  1578554626121
# 3  1578554626121
# 4  1578554656179
