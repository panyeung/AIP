# %%
import pandas as pd
import numpy as np
import json

# %%
# open traffic.txt file
with open("CityIQ-Starter-Code-Python/traffic.txt", "r") as file:
    data = file.read()
jsondata = json.loads(data)

# normalize json
from pandas.io.json import json_normalize
df = pd.DataFrame(json_normalize(jsondata))
df.head()
# Out:
#   locationUid                              assetUid eventType      timestamp  \
# 0    f57e7d59  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT  1578554595996
# 1    f57e7d59  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT  1578554595996
# 2    f57e7d59  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT  1578554626121
# 3    f57e7d59  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT  1578554626121
# 4    f57e7d59  0cd1f557-0f30-4785-9898-c5acbbbf1bc6     TFEVT  1578554656179
#
#   properties.speedUnit   properties.eventUid properties.directionUnit  \
# 0       METERS_PER_SEC  MTU3ODU1NDU5NTk5Ng==                   DEGREE
# 1       METERS_PER_SEC  MTU3ODU1NDU5NTk5Ng==                   DEGREE
# 2       METERS_PER_SEC  MTU3ODU1NDYyNjEyMQ==                   DEGREE
# 3       METERS_PER_SEC  MTU3ODU1NDYyNjEyMQ==                   DEGREE
# 4       METERS_PER_SEC  MTU3ODU1NDY1NjE3OQ==                   DEGREE
#
#   properties.counter_direction_vehicleType properties.vehicleType  \
# ...

# %%
df.columns
# Out:
# Index(['locationUid', 'assetUid', 'eventType', 'timestamp',
#        'properties.speedUnit', 'properties.eventUid',
#        'properties.directionUnit', 'properties.counter_direction_vehicleType',
#        'properties.vehicleType', 'measures.counter_direction_speed',
#        'measures.vehicleCount', 'measures.counter_direction_vehicleCount',
#        'measures.counter_direction', 'measures.speed', 'measures.direction'],
#       dtype='object')
